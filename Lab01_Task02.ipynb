# %% [markdown]
# <a href="https://colab.research.google.com/github/sadumina/DL-lab-01-/blob/main/Lab01_Task02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("Au_nanoparticle_dataset.csv")

# %%
df.head()
# Out:
#    ID    T       tau  time  N_total  N_bulk  N_surface        Volume    R_min  \
# 0   1  273  0.000025     1     1599    1014        585  2.710000e-26  15.5898
# 1   2  273  0.000025     2     1642    1034        608  2.780000e-26  15.3996
# 2   3  273  0.000025     3     4637    3365       1272  7.850000e-26  21.9199
# 3   4  273  0.000025     4     7189    5292       1897  1.220000e-25  23.2542
# 4   5  273  0.000025     5    11004    8508       2496  1.860000e-25  27.1200
#
#      R_max  ...  q6q6_S14  q6q6_S15  q6q6_S16  q6q6_S17  q6q6_S18  q6q6_S19  \
# 0  19.4516  ...         0         0         0         0         0         0
# 1  24.1755  ...         0         0         0         0         0         0
# 2  31.0305  ...         0         0         0         0         0         0
# 3  37.8795  ...         0         0         0         0         0         0
# 4  39.7614  ...         0         0         0         0         0         0
#
# ...

# %%
df_new = df[['N_total', 'N_bulk', 'N_surface', 'R_avg']]

# %%
df.head(20)
# Out:
#     ID    T       tau  time  N_total  N_bulk  N_surface        Volume  \
# 0    1  273  0.000025     1     1599    1014        585  2.710000e-26
# 1    2  273  0.000025     2     1642    1034        608  2.780000e-26
# 2    3  273  0.000025     3     4637    3365       1272  7.850000e-26
# 3    4  273  0.000025     4     7189    5292       1897  1.220000e-25
# 4    5  273  0.000025     5    11004    8508       2496  1.860000e-25
# 5    6  273  0.000025     6    13375   10768       2607  2.260000e-25
# 6    7  273  0.000025     7    13795   11155       2640  2.340000e-25
# 7    8  273  0.000025     8    13947   11304       2643  2.360000e-25
# 8    9  273  0.000025     9    14020   11357       2663  2.370000e-25
# 9   10  273  0.000025    10    14056   11389       2667  2.380000e-25
# 10  11  273  0.000050     1     1534     966        568  2.600000e-26
# 11  12  273  0.000050     2     1559     974        585  2.640000e-26
# ...

# %%
print('Mean of the Dataset fillterd')
df_new.mean()
# Out:
# Mean of the Dataset fillterd
# N_total      3476.786500
# N_bulk       2521.550250
# N_surface     955.236250
# R_avg          20.654363
# dtype: float64

# %%
print('Median of the Dataset fillterd')
df_new.median()
# Out:
# Median of the Dataset fillterd
# N_total      1867.00000
# N_bulk       1199.00000
# N_surface     666.00000
# R_avg          18.62925
# dtype: float64

# %%
print('Quartiles of the Dataset fillterd')
df_new.quantile([0.25, 0.5, 0.75])
# Out:
# Quartiles of the Dataset fillterd
#       N_total   N_bulk  N_surface      R_avg
# 0.25   1061.0   618.75     437.00  15.160725
# 0.50   1867.0  1199.00     666.00  18.629250
# 0.75   4503.0  3183.00    1301.75  25.525125

# %%
df_new.describe()
# Out:
#             N_total        N_bulk   N_surface        R_avg
# count   4000.000000   4000.000000  4000.00000  4000.000000
# mean    3476.786500   2521.550250   955.23625    20.654363
# std     3679.286769   2976.232459   721.87022     7.610716
# min      236.000000     89.000000   137.00000     8.528600
# 25%     1061.000000    618.750000   437.00000    15.160725
# 50%     1867.000000   1199.000000   666.00000    18.629250
# 75%     4503.000000   3183.000000  1301.75000    25.525125
# max    14277.000000  11580.000000  3190.00000    39.239200

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %% [markdown]
# Plot the histogram of each of these features in a 1x4 layout.

# %%
fig, axes = plt.subplots(1, 4, figsize=(20, 5))
columns = ['N_total', 'N_bulk', 'N_surface', 'R_avg']
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']

for i, col in enumerate(columns):
    sns.histplot(df_new[col], kde=True, ax=axes[i], color=colors[i])
    axes[i].set_title(f'Distribution of {col}')
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
sns.pairplot(df_new)
plt.show()

# %% [markdown]
# 6. Add the below code and change it such that,
# a. Plots on the diagonal contains the histogram of each feature along with the kernal
# density estimation plot.
# b. Plots on the lower half [g.map_lower] contains the bivariate kernal density
# estimation plot.

# %%
g = sns.PairGrid(df_new)
g.map_upper(sns.histplot) #bivariate histogram
g.map_diag(sns.histplot)
g.map_lower(sns.kdeplot)
